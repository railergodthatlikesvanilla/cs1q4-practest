# %% [markdown]
# <a href="https://colab.research.google.com/github/railergodthatlikesvanilla/cs1q4-practest/blob/main/cs1q4_practest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def get_sum(a,b):
  return a + b

name = input("hey whats your name?: " )
score = int(input("how many test scores do you want to put?: "))
a = int(input("What is your test score?: "))
b = int(input("What is your test score?: "))

total_score = get_sum(a,b)
print("Your total score is: ", total_score)

average_grade = (a + b) / 2
print("Your average grade is: ", average_grade)

if average_grade >= 75:
  print("PASSED")
else:
  print("FAILED")
# Out:
# hey whats your name?: asd
# how many test scores do you want to put?: 2
# What is your test score?: 324
# What is your test score?: 23
# Your total score is:  347
# Your average grade is:  173.5
# PASSED
